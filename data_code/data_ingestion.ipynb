# %%
df_cal = spark.read.format('csv')\
            .option("header",True)\
            .option("inferSchema",True)\
            .load('/Volumes/retail_sales_lakehouse/default/bronze_layer_dataset/AdventureWorks_Calendar/')

# %%
df_cus = spark.read.format('csv')\
            .option("header",True)\
            .option("inferSchema",True)\
            .load('/Volumes/retail_sales_lakehouse/default/bronze_layer_dataset/AdventureWorks_Customers/')

# %%
df_procat = spark.read.format('csv')\
            .option("header",True)\
            .option("inferSchema",True)\
            .load('/Volumes/retail_sales_lakehouse/default/bronze_layer_dataset/AdventureWorks_Product_Categories/')

# %%
df_sales = spark.read.format('csv')\
            .option("header",True)\
            .option("inferSchema",True)\
            .load('/Volumes/retail_sales_lakehouse/default/bronze_layer_dataset/AdventureWorks_Sales*')

# %%
df_pro = spark.read.format('csv')\
            .option("header",True)\
            .option("inferSchema",True)\
            .load('/Volumes/retail_sales_lakehouse/default/bronze_layer_dataset/AdventureWorks_Products/')

# %%
df_returns = spark.read.format('csv')\
            .option("header",True)\
            .option("inferSchema",True)\
            .load('/Volumes/retail_sales_lakehouse/default/bronze_layer_dataset/AdventureWorks_Returns/')

# %%
df_ter = spark.read.format('csv')\
            .option("header",True)\
            .option("inferSchema",True)\
            .load('/Volumes/retail_sales_lakehouse/default/bronze_layer_dataset/AdventureWorks_Territories/')

# %%
df_subcat = spark.read.format('csv')\
            .option("header",True)\
            .option("inferSchema",True)\
            .load('/Volumes/retail_sales_lakehouse/default/bronze_layer_dataset/Product_Subcategories/')
